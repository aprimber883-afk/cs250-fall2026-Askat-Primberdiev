# %% [markdown]
# <a href="https://colab.research.google.com/github/aprimber883-afk/cs250-fall2026-Askat-Primberdiev/blob/main/labs/L00_Primberdiev_Askat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Askat Primberdiev"
github_username = "aprimber883-afk"
course = "CS 250"

print("Student:", name)
print("GitHub:", github_username)
print("Course:", course)
print("Colab + GitHub setup complete!")

favorite_number = 2

print("My favorite number is:", favorite_number)
print("Twice my favorite number is:", favorite_number * 2)
# Out:
# Student: Askat Primberdiev
# GitHub: aprimber883-afk
# Course: CS 250
# Colab + GitHub setup complete!
# My favorite number is: 2
# Twice my favorite number is: 4
